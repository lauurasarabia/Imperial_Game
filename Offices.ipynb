# %%
# %run -i 'python_functions/requirements.py'

# %%
token = os.getenv("token")

# %% [markdown]
# # Offices🏢

# %% [markdown]
# We have found three possible places to install our company in San Francisco:

# %%
offices = [{
    'name': 'New Montgomery St', 'lat': 37.7874603, 'lon': -122.4027121, "url": "https://www.instantoffices.com/en-us/us/available-office-space/san-francisco/new-montgomery-street-35987"},
    {'name': 'Mission St', 'lat': 37.7783494, 'lon': -122.4142472, "url": "https://www.instantoffices.com/en-us/us/available-office-space/san-francisco/mission-street-53593"},
    {'name': 'Brannan St', 'lat': 37.7771255, 'lon': -122.4002788, "url": "https://www.instantoffices.com/en-us/us/available-office-space/san-francisco/brannan-st-49819"
    }]
officesdf = pd.DataFrame(offices)
officesdf
# Out:
#                 name        lat         lon  \
# 0  New Montgomery St  37.787460 -122.402712
# 1         Mission St  37.778349 -122.414247
# 2         Brannan St  37.777125 -122.400279
#
#                                                  url
# 0  https://www.instantoffices.com/en-us/us/availa...
# 1  https://www.instantoffices.com/en-us/us/availa...
# 2  https://www.instantoffices.com/en-us/us/availa...

# %%
to_mongo('offices', officesdf)

# %% [markdown]
# Pointing them in a map:

# %%
gdf = gpd.GeoDataFrame(officesdf, geometry=gpd.points_from_xy(officesdf["lon"], officesdf["lat"]))

# %%
Map(Layer(gdf, "color:blue", popup_hover=[popup_element("name", "Office")]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {
#       // throw out eval line/column and use top-most line/column number
#       parts[2] = submatch[1]; // url
#       parts[3] = submatch[2]; // line
#       parts[4] = submatch[3]; // column
#     }
#
#     return {
#       file: !isNative ? parts[2] : null,
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: isNative ? [parts[2]] : [],
#       lineNumber: parts[3] ? +parts[3] : null,
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseWinjs(line) {
#     const parts = winjsRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     return {
#       file: parts[2],
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: [],
#       lineNumber: +parts[3],
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseGecko(line) {
#     const parts = geckoRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isEval = parts[3]

# %% [markdown]
# ## New Montgomery St

# %% [markdown]
# ### Schools

# %%
df_nmschools = schools_newmontgomery(
    "https://api.foursquare.com/v3/places/search?ll=37.787460%2C-122.402712&radius=1000&categories=12058&limit=15"
)
df_nmschools[:3]
# Out:
#                               name        lat         lon
# 0            Decker Communications  37.789616 -122.400368
# 1  Notre Dame Des Victoires School  37.791201 -122.406555
# 2            AltSchool Yerba Buena  37.781815 -122.401127

# %%
to_mongo('nmschools', df_nmschools)

# %% [markdown]
# ### Starbucks

# %%
df_strbucksnm = strbucks_newmontgomery(
    "https://api.foursquare.com/v3/places/search?ll=37.787460%2C-122.402712&radius=1000&chains=ab4c54c0-d68a-012e-5619-003048cad9da&limit=15"
)
df_strbucksnm[:3]
# Out:
#         name        lat         lon
# 0  Starbucks  37.787664 -122.401113
# 1  Starbucks  37.789599 -122.401872
# 2  Starbucks  37.786145 -122.405612

# %%
to_mongo('strbucksnm', df_strbucksnm)

# %% [markdown]
# ### Distance from airport

# %%
office_nm = (37.787460, -122.402712)  # (latitude, longitude) 
airport_sfco = (37.6213171, -122.3811441)

print(geodesic(office_nm, airport_sfco).kilometers)
# Out:
# 18.538171990995558

# %% [markdown]
# ### Vegan restaurants

# %%
df_vegannm = vegan_newmontgomery(
    "https://api.foursquare.com/v3/places/search?query=vegan&ll=37.787460%2C-122.402712&radius=1000&categories=13377&limit=15"
)
df_vegannm[:3]
# Out:
#                                        name        lat         lon
# 0               Enjoy Vegetarian Restaurant  37.795717 -122.405173
# 1  The Lucky Creation Vegetarian Restaurant  37.795174 -122.407148
# 2                                Sweetgreen  37.787182 -122.398432

# %%
to_mongo('vegannm', df_vegannm)

# %% [markdown]
# ### Basketball Stadium

# %%
df_basketnm = basket_newmontgomery(
    "https://api.foursquare.com/v3/places/search?query=basketball%20stadium&ll=37.787460%2C-122.402712&radius=10000&categories=18006&limit=15"
)
df_basketnm[:3]
# Out:
#                       name        lat         lon
# 0  Berry Basketball Courts  37.772031 -122.397898
# 1          Soma Rec Center  37.778838 -122.406328
# 2      Arterra Mission Bay  37.771896 -122.397532

# %%
to_mongo('basketnm', df_basketnm)

# %% [markdown]
# ### Night Clubs

# %%
df_nightnm = night_newmontgomery("https://api.foursquare.com/v3/places/search?ll=37.787460%2C-122.402712&radius=1000&categories=10032&limit=15"
    )
df_nightnm[:3]
# Out:
#                      name        lat         lon
# 0                The View  37.785207 -122.404625
# 1                Club Six  37.781406 -122.409490
# 2  Southside Spirit House  37.787118 -122.397568

# %%
to_mongo('nightnm', df_nightnm)

# %% [markdown]
# ### New Montgomery St Map

# %%
offices_gdf = add_geometry(officesdf)
nmschools_gdf = add_geometry(df_nmschools)
strbucksnm_gdf = add_geometry(df_strbucksnm)
vegannm_gdf = add_geometry(df_vegannm)
basketnm_gdf = add_geometry(df_basketnm)
nightnm_gdf = add_geometry(df_nightnm)

# %%
map_newmont(offices_gdf, nmschools_gdf, strbucksnm_gdf, vegannm_gdf, basketnm_gdf, nightnm_gdf)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--vertical as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#   <as-layer-selector id=&quot;layer-selector&quot;>
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-0-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;NightClubs&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer0_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-1-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Basketball&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer1_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-2-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;VeganRestaurants&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer2_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-3-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Starbucks&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer3_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-4-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Schools&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer4_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-5-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Offices&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer5_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#   </as-layer-selector>
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&q

# %% [markdown]
# ## Mission St

# %% [markdown]
# ### Schools

# %%
df_schmission = schools_mission(
    "https://api.foursquare.com/v3/places/search?ll=37.778349%2C-122.414247&radius=1000&categories=12058&limit=15"
)
df_schmission[:3]
# Out:
#                                     name        lat         lon
# 0            Tenderloin Community School  37.781867 -122.419696
# 1  San Francisco Unified School District  37.779265 -122.422123
# 2   French American International School  37.775465 -122.421827

# %%
to_mongo('schmission', df_schmission)

# %% [markdown]
# ### Starbucks

# %%
df_strbcksmission = starbucks_mission(
    "https://api.foursquare.com/v3/places/search?ll=37.778349%2C-122.414247&radius=1000&chains=ab4c54c0-d68a-012e-5619-003048cad9da&limit=15"
)
df_strbcksmission[:3]
# Out:
#         name        lat         lon
# 0  Starbucks  37.777119 -122.419416
# 1  Starbucks  37.777050 -122.417333
# 2  Starbucks  37.784144 -122.407429

# %%
to_mongo('strbcksmission', df_strbcksmission)

# %% [markdown]
# ### Distance from airport

# %%
office_mission = (37.778349, -122.414247)  # (latitude, longitude)
airport_sfco = (37.6213171, -122.3811441)


print(geodesic(office_mission, airport_sfco).kilometers)
# Out:
# 17.671893902013668

# %% [markdown]
# ### Vegan restaurants

# %%
df_veganmiss = vegan_mission(
    "https://api.foursquare.com/v3/places/search?query=vegan&ll=37.778349%2C-122.414247&radius=1000&categories=13377&limit=15"
)
df_veganmiss[:3]
# Out:
#                               name        lat         lon
# 0                     Ananda Fuara  37.777890 -122.416164
# 1      Golden Era Vegan Restaurant  37.781359 -122.416942
# 2  Thai Idea Vegetarian Restaurant  37.783391 -122.418998

# %%
to_mongo('veganmiss', df_veganmiss)

# %% [markdown]
# ### Basketball Stadium

# %%
df_basketmiss = basket_mission(
    "https://api.foursquare.com/v3/places/search?query=basketball%20stadium&ll=37.778349%2C-122.414247&radius=10000&categories=18006&limit=15"
)
df_basketmiss[:3]
# Out:
#                       name        lat         lon
# 0  Berry Basketball Courts  37.772031 -122.397898
# 1          Soma Rec Center  37.778838 -122.406328
# 2      Arterra Mission Bay  37.771896 -122.397532

# %%
to_mongo('basketmiss', df_basketmiss)

# %% [markdown]
# ### Night Clubs

# %%
df_nightmiss = night_mission("https://api.foursquare.com/v3/places/search?ll=37.778349%2C-122.414247&radius=1000&categories=10032&limit=15"
    )
df_nightmiss[:3]
# Out:
#              name        lat         lon
# 0           Oasis  37.771782 -122.414442
# 1  F8 1192 Folsom  37.775283 -122.409986
# 2        Club Six  37.781406 -122.409490

# %%
to_mongo('nightmiss', df_nightmiss)

# %% [markdown]
# ### Mission St Map

# %%
schmission_gdf = add_geometry(df_schmission)
strbucksmiss_gdf = add_geometry(df_strbcksmission)
veganmiss_gdf = add_geometry(df_veganmiss)
basketmiss_gdf = add_geometry(df_basketmiss)
nightmiss_gdf = add_geometry(df_nightmiss)

# %%
map_mission(offices_gdf, schmission_gdf, strbucksmiss_gdf, veganmiss_gdf, basketmiss_gdf, nightmiss_gdf)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--vertical as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#   <as-layer-selector id=&quot;layer-selector&quot;>
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-0-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;NightClubs&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer0_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-1-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Basketball&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer1_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-2-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;VeganRestaurants&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer2_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-3-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Starbucks&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer3_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-4-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Schools&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer4_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-5-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Offices&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer5_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#   </as-layer-selector>
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&q

# %% [markdown]
# ## Brannan St

# %% [markdown]
# ### Schools

# %%
df_schoolsbrannan = schools_brannan(
    "https://api.foursquare.com/v3/places/search?ll=37.777125%2C-122.400279&radius=1000&categories=12058&limit=15"
)
df_schoolsbrannan[:3]
# Out:
#                                     name        lat         lon
# 0    Bessie Carmichael Elementary School  37.776165 -122.406672
# 1                  AltSchool Yerba Buena  37.781815 -122.401127
# 2  San Francisco Unified School District  37.780650 -122.400556

# %%
to_mongo('schoolsbrannan', df_schoolsbrannan)

# %% [markdown]
# ### Starbucks

# %%
df_strbcksbrannan = starbucks_brannan(
    "https://api.foursquare.com/v3/places/search?ll=37.777125%2C-122.400279&radius=1000&chains=ab4c54c0-d68a-012e-5619-003048cad9da&limit=15"
)
df_strbcksbrannan[:3]
# Out:
#         name        lat         lon
# 0  Starbucks  37.784470 -122.404008
# 1  Starbucks  37.770241 -122.403384
# 2  Starbucks  37.784199 -122.404135

# %%
to_mongo('strbcksbrannan', df_strbcksbrannan)

# %% [markdown]
# ### Distance from airport

# %%
office_brannan = (37.777125, -122.400279)  # (latitude, longitude)
airport_sfco = (37.6213171, -122.3811441)


print(geodesic(office_brannan, airport_sfco).kilometers)
# Out:
# 17.37538214162873

# %% [markdown]
# ### Vegan restaurants

# %%
df_veganbrann = vegan_brannan(
    "https://api.foursquare.com/v3/places/search?query=vegan&ll=37.777125%2C-122.400279&radius=1000&categories=13377&limit=15"
)
df_veganbrann[:3]
# Out:
#               name        lat         lon
# 0          Plant B  37.776853 -122.402670
# 1   Roz Ka Affaire  37.776665 -122.402687
# 2  Thai Basil Cart  37.776768 -122.402622

# %%
to_mongo('veganbrann', df_veganbrann)

# %% [markdown]
# ### Basketball Stadium

# %%
df_basketbrann = basket_brannan(
    "https://api.foursquare.com/v3/places/search?query=basketball%20stadium&ll=37.777125%2C-122.400279&radius=10000&categories=18006&limit=15"
)
df_basketbrann[:3]
# Out:
#                       name        lat         lon
# 0  Berry Basketball Courts  37.772031 -122.397898
# 1          Soma Rec Center  37.778838 -122.406328
# 2      Arterra Mission Bay  37.771896 -122.397532

# %%
to_mongo('basketbrann', df_basketbrann)

# %% [markdown]
# ### Night Clubs

# %%
df_nightbrann = night_brannan("https://api.foursquare.com/v3/places/search?ll=37.777125%2C-122.400279&radius=1000&categories=10032&limit=15"
    )
df_nightbrann[:3]
# Out:
#              name        lat         lon
# 0  F8 1192 Folsom  37.775283 -122.409986
# 1        Club Six  37.781406 -122.409490
# 2        The View  37.785207 -122.404625

# %%
to_mongo('nightbrann', df_nightbrann)

# %% [markdown]
# ### Brannan St Map

# %%
schoolsbrannan_gdf = add_geometry(df_schoolsbrannan)
strbcksbrannan_gdf = add_geometry(df_strbcksbrannan)
veganbrann_gdf = add_geometry(df_veganbrann)
basketbrann_gdf = add_geometry(df_basketbrann)
nightbrann_gdf = add_geometry(df_nightbrann)

# %%
map_brannan(offices_gdf, schoolsbrannan_gdf, strbcksbrannan_gdf, veganbrann_gdf, basketbrann_gdf, nightbrann_gdf)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--vertical as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#   <as-layer-selector id=&quot;layer-selector&quot;>
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-0-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;NightClubs&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer0_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-1-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Basketball&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer1_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-2-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;VeganRestaurants&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer2_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-3-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Starbucks&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer3_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-4-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Schools&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer4_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-5-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;Offices&quot;
#                 description=&quot;&quot;>
#                 <as-legend-default id=&quot;layer5_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-default>
#
#               </as-legend>
#
#
#         </div>
#
#
#   </as-layer-selector>
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&q
